# %%
import numpy as np

file1 = open("c_vals", "rb")
cv = np.load(file1)

file2 = open("params", "rb")
par = np.load(file2)

print(cv)
print(par)
# Out:
# [4.06556664 4.09303079 4.06084575 4.04219611 4.19520689 4.29322475
#  4.78199278 4.07356416 4.46203024 4.00739703 4.15222468 4.46869166
#  4.55080834 4.77375501 4.19427611 4.87308183 4.54232474 4.20161468
#  4.09859905 4.0368276  4.41541453 4.15145354 4.51982522 4.14708474
#  4.64086078 4.1149798  4.27197076 3.96338303 4.01918885 4.25139049
#  4.08924624 4.11353448 4.7487777  4.07682501 4.00212574 4.05692398
#  4.08387477 4.88393827 4.52107167 4.32562648 4.10067545 4.82865042
#  4.24194395 4.16555757 4.22790195 4.74396246 4.05531679 4.78384426
#  4.08721653 4.02895496 4.76005652 4.11018161 4.66900657 4.66488757
#  4.83324165 4.34254728 4.01320406 4.01325567 4.05108757 4.72834939
#  4.56323431 4.70002717 4.37012977 4.93328147 4.04712889 4.60385554
#  4.66852926 4.04498856 4.11583116 4.74323038 4.08240254 4.63659995
#  4.53987185 4.80075    4.80485947 4.18111    4.89088155 4.96671374
#  4.73012921 4.56471946 4.01890864 4.16072962 4.68603533 4.62701578
# ...

# %%
cv.min()
# Out:
# 3.963383027286806

# %%
np.where(cv == cv.min())
# Out:
# (array([27], dtype=int64),)

# %%
par[27]
# Out:
# array([[  0.24283578, -18.14389477,   0.15018159,  -0.81017487,
#           1.33106479,  -8.92620624,   0.51011689,  -0.29496139,
#           0.11514634,  -3.60908841],
#        [-26.42875454,  -0.57860042,   0.43339335,   0.50791955,
#          -2.41160314,  -0.4728843 ,  -0.10806604,   0.08810694,
#          -0.87597278,  -0.34153264]])
